# %%
import json

# %%
with open("sessions_lionking_lionking.mp4-e3381617-812c-41ed-8b5c-2d6153b57893 (1).json",'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# %%
data.keys()
# Out:
# dict_keys(['jobName', 'accountId', 'status', 'results'])

# %%
data['results']
# Out:
# {'transcripts': [{'transcript': 'נע רבתי. סבבה. בני הציבית לבוא הברה ו בתי לא והיום שהגחנו מבטן ויצאנו לאור העולם הן לא נספיק לעשות את הכול ולראות את כל מה שקיים יותר מדי קורה כל יום שהיה ועומד שוב. בשיחת החמה השקיעה כל הברואים משתדלים רק לחיות שדה גלגל. בן יו לא זה מרגיש זה לא זה ב אני'}],
#  'items': [{'id': 0,
#    'type': 'pronunciation',
#    'alternatives': [{'confidence': '0.272', 'content': 'נע'}],
#    'start_time': '2.579',
#    'end_time': '2.779'},
#   {'id': 1,
#    'type': 'pronunciation',
#    'alternatives': [{'confidence': '0.004', 'content': 'רבתי'}],
#    'start_time': '6.699',
#    'end_time': '7.03'},
#   {'id': 2,
#    'type': 'punctuation',
#    'alternatives': [{'confidence': '0.0', 'content': '.'}]},
#   {'id': 3,
#    'type': 'pronunciation',
#    'alternatives': [{'confidence': '0.009', 'content': 'סבבה'}],
#    'start_time': '7.269',
#    'end_time': '7.67'},
#   {'id': 4,
#    'type': 'punctuation',
# ...

# %%
data['results']['audio_segments']
# Out:
# [{'id': 0,
#   'transcript': 'נע',
#   'start_time': '2.46',
#   'end_time': '2.809',
#   'items': [0]},
#  {'id': 1,
#   'transcript': 'רבתי. סבבה.',
#   'start_time': '6.67',
#   'end_time': '7.86',
#   'items': [1, 2, 3, 4]},
#  {'id': 2,
#   'transcript': 'בני',
#   'start_time': '9.59',
#   'end_time': '10.239',
#   'items': [5]},
#  {'id': 3,
#   'transcript': 'הציבית',
#   'start_time': '15.64',
#   'end_time': '16.62',
#   'items': [6]},
#  {'id': 4,
#   'transcript': 'לבוא',
#   'start_time': '18.78',
#   'end_time': '19.28',
#   'items': [7]},
#  {'id': 5,
#   'transcript': 'הברה ו',
#   'start_time': '22.909',
#   'end_time': '24.85',
#   'items': [8, 9]},
#  {'id': 6,
#   'transcript': 'בתי',
#   'start_time': '40.15',
#   'end_time': '41.61',
#   'items': [10]},
#  {'id': 7,
#   'transcript': 'לא',
#   'start_time': '45.5',
#   'end_time': '45.77',
#   'items': [11]},
#  {'id': 8,
#   'transcript': 'והיום שהגחנו מבטן ויצאנו לאור העולם',
#   'start_time': '53.529',
# ...
